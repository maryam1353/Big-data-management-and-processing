# %% [markdown]
# ## Producer 1
#
# Producer 1 produces the data from 'climate_streaming.csv' and sends it to the Apache Spark Stream for further processing. Producer 1 is a Kafka Producer and becomes a part of the Spark Stream through kafka.
#
# The csv is read and each line is processes as a list of dictionaries. Each dictionary represents a line from the file. The dictionary has the key-value pairs as corresponding to the header and respective value in the csv file.
#
# A random entry from the list is chosen to be publised as a message to the stream every 5 seconds and is processed into a byte stream with the topic name as 'Producer'.

# %% [markdown]
# ### Importing Libraries

# %%
# import statements
from time import sleep
from json import dumps
from kafka import KafkaProducer
import random
import datetime as dt
import json

# %% [markdown]
# ### Publish Message
# Method used for publishing the message to the spark stream.

# %%
def publish_message(producer_instance, topic_name, key, data):
    try:
        # Converts the values and keys to bytes for processing.
        value_bytes = bytes(data, encoding='utf-8')
        key_bytes = bytes(key, encoding='utf-8')
        # Published the message for the given instance.
        producer_instance.send(topic_name, key=key_bytes, value=value_bytes)
        print('Message published successfully. ' + data)
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))

# %% [markdown]
# ### Connect Kafka Producer
# Method used for creating a kakfa producer.

# %%
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=['127.0.0.1:9092'],
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer

# %% [markdown]
# ### Read Data

# %%
def read_data():
    data_list = []
    # Read file
    file = open("climate_streaming.csv","r")
    index = 0
    for line in file:
        # Iterate over lines of file
        file_list = line.split(',')
        # Get headers
        if index == 0:
            headers = [item.strip() for item in file_list]
            index += 1
            continue
        # Add the line to a dictionary according to the headers
        else:
            jsonElem = {}
            jsonElem[headers[0]] = file_list[0]
            jsonElem[headers[1]] = file_list[1]
            jsonElem[headers[2]] = file_list[2]
            jsonElem[headers[3]] = file_list[3]
            jsonElem[headers[4]] = file_list[4]
            jsonElem[headers[5]] = file_list[5]
            jsonElem[headers[6]] = file_list[6].strip()
        data_list.append(jsonElem)
                               
    return data_list

# %% [markdown]
# ### Select record and publish message

# %%
topic = 'Producer'
print('Publishing records..')
producer01 = connect_kafka_producer()
data_list = read_data()

while True:
    # Generate random number to select a line for the stream
    random_number = random.randint(0,len(data_list)-1)
    data = data_list[random_number]
    # Add sender id and time for record
    data['Sender_ID'] = 'Producer01'
    data['Created_Time'] = str(dt.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    # Publish message
    publish_message(producer01, topic, 'Producer01', json.dumps(data))
    # Sleep for 5 seconds
    sleep(5)
# Out:
# Publishing records..
# Message published successfully. {"windspeed_knots": "4.4", "max_wind_speed": "8.9", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:37:19", "longitude": "148.1", "latitude": "-37.466", "relative_humidity": "49.4", "air_temperature_celcius": "12"}
# Message published successfully. {"windspeed_knots": "9.3", "max_wind_speed": "15", "Sender_ID": "Producer01", "precipitation": "0.20G", "Created_Time": "2019-05-24 21:37:25", "longitude": "144.3142", "latitude": "-36.4325", "relative_humidity": "61", "air_temperature_celcius": "26"}
# Message published successfully. {"windspeed_knots": "10.5", "max_wind_speed": "15", "Sender_ID": "Producer01", "precipitation": "0.28G", "Created_Time": "2019-05-24 21:37:30", "longitude": "141.828", "latitude": "-37.1104", "relative_humidity": "46.2", "air_temperature_celcius": "11"}
# Message published successfully. {"windspeed_knots": "8.8", "max_wind_speed": "15", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:37:35", "longitude": "143.0015", "latitude": "-37.5915", "relative_humidity": "52", "air_temperature_celcius": "17"}
# Message published successfully. {"windspeed_knots": "12.5", "max_wind_speed": "19", "Sender_ID": "Producer01", "precipitation": "0.03G", "Created_Time": "2019-05-24 21:37:40", "longitude": "142.7134", "latitude": "-36.7685", "relative_humidity": "48.2", "air_temperature_celcius": "14"}
# Message published successfully. {"windspeed_knots": "10.8", "max_wind_speed": "16.9", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:37:45", "longitude": "146.7777", "latitude": "-37.1815", "relative_humidity": "50.4", "air_temperature_celcius": "17"}
# Message published successfully. {"windspeed_knots": "6.9", "max_wind_speed": "8.9", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 21:37:50", "longitude": "141.8047", "latitude": "-37.0046", "relative_humidity": "41.4", "air_temperature_celcius": "10"}
# Message published successfully. {"windspeed_knots": "9.3", "max_wind_speed": "13", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:37:55", "longitude": "149.277", "latitude": "-37.611", "relative_humidity": "49.4", "air_temperature_celcius": "18"}
# Message published successfully. {"windspeed_knots":
"max_wind_speed": "15.9", "Sender_ID": "Producer01", "precipitation": "0.01G", "Created_Time": "2019-05-24 21:40:10", "longitude": "143.1906", "latitude": "-36.2669", "relative_humidity": "42.7", "air_temperature_celcius": "12"}
# Message published successfully. {"windspeed_knots": "6.9", "max_wind_speed": "12", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:40:15", "longitude": "149.233", "latitude": "-37.644", "relative_humidity": "58", "air_temperature_celcius": "22"}
# Message published successfully. {"windspeed_knots": "6.7", "max_wind_speed": "11.1", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:40:20", "longitude": "144.165", "latitude": "-36.764", "relative_humidity": "52.4", "air_temperature_celcius": "14"}
# Message published successfully. {"windspeed_knots": "11.7", "max_wind_speed": "20", "Sender_ID": "Producer01", "precipitation": "0.02G", "Created_Time": "2019-05-24 21:40:25", "longitude": "145.1635", "latitude": "-36.778", "relative_humidity": "46.3", "air_temperature_celcius": "17"}
# Message published successfully. {"windspeed_knots": "9.4", "max_wind_speed": "14", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:40:30", "longitude": "148.05", "latitude": "-37.368", "relative_humidity": "41.4", "air_temperature_celcius": "10"}
# Message published successfully. {"windspeed_knots": "9.3", "max_wind_speed": "15.9", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:40:35", "longitude": "146.8024", "latitude": "-37.1875", "relative_humidity": "58.3", "air_temperature_celcius": "28"}
# Message published successfully. {"windspeed_knots": "4.7", "max_wind_speed": "8", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 21:40:40", "longitude": "141.27", "latitude": "-37.247", "relative_humidity": "43.1", "air_temperature_celcius": "10"}
# Message published successfully. {"windspeed_knots": "11", "max_wind_speed": "16.9", "Sender_ID": "Producer01", "precipitation": "0.47G", "Created_Time": "2019-05-24 21:40:45", "longitude": "148.064", "latitude": "-37.335", "relative_humidity": "41", "air_temperature_celcius": "8"}
# Message published successfully. {"windspeed_knots": "5.3", "max_wind_speed": "12", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 21:40:50", "longitude": "148.089", "latitude": "-37.462", "relative_humidity": "40.7", "air_temperature_celcius": "8"}
# Message published successfully. {"windspeed_knots": "10.5", "max_wind_speed": "20", "Sender_ID": "Producer01", "precipitation": "0.12G", "Created_Time": "2019-05-24 21:40:55", "longitude": "145.614", "latitude": "-35.889", "relative_humidity": "49.2", "air_temperature_celcius": "14"}
# Message published successfully. {"windspeed_knots": "8.1", "max_wind_speed": "15", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:41:00", "longitude": "141.0271", "latitude": "-38.0427", "relative_humidity": "52.9", "air_temperature_celcius": "19"}
# Message published successfully. {"windspeed_knots": "12.2", "max_wind_speed": "21", "Sender_ID": "Producer01", "precipitation": "0.24G", "Created_Time": "2019-05-24 21:41:05", "longitude": "143.365", "latitude": "-37.475", "relative_humidity": "49.9", "air_temperature_celcius": "17"}
# Message published successfully. {"windspeed_knots": "4.9", "max_wind_speed": "8", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:41:10", "longitude": "148.056", "latitude": "-37.384", "relative_humidity": "43.2", "air_temperature_celcius": "9"}
# Message published successfully. {"windspeed_knots": "5.7", "max_wind_speed": "11.1", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:41:15", "longitude": "142.785", "latitude": "-36.275", "relative_humidity": "30.8", "air_temperature_celcius": "6"}
# Message published successfully. {"windspeed_knots": "11.4", "max_wind_speed": "16.9", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 21:41:20", "longitude": "146.108", "latitude": "-36.779", "relative_humidity": "42", "air_temperature_celcius": "13"}
# Message published successfully. {"windspeed_knots": "8.9", "max_wind_speed": "15", "Sender_ID": "Producer01", "precipitation": "0.98G", "Created_Time": "2019-05-24 21:41:25", "longitude": "149.31", "latitude": "-37.59", "relative_humidity": "57.2", "air_temperature_celcius": "19"}
# Message published successfully. {"windspeed_knots": "6.7", "max_wind_speed": "13", "Sender_ID": "Producer01", "precipitation": "0.01G", "Created_Time": "2019-05-24 21:41:30", "longitude": "142.3282", "latitude": "-36.8948", "relative_humidity": "41.2", "air_temperature_celcius": "9"}
# Message published successfully. {"windspeed_knots": "8", "max_wind_speed": "13", "Sender_ID": "Producer01", "precipitation": "0.08G", "Created_Time": "2019-05-24 21:41:35", "longitude": "146.155", "latitude": "-36.273", "relative_humidity": "56.3", "air_temperature_celcius": "22"}
# Message published successfully. {"windspeed_knots": "7", "max_wind_speed": "13", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:41:40", "longitude": "145.25", "latitude": "-37.903", "relative_humidity": "62.3", "air_temperature_celcius": "24"}
# Message published successfully. {"windspeed_knots": "6.8", "max_wind_speed": "15.9", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 21:41:45", "longitude": "143.791", "latitude": "-35.962", "relative_humidity": "49.9", "air_temperature_celcius": "14"}
# Message published successfully. {"windspeed_knots": "4.8", "max_wind_speed": "8.9", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:41:50", "longitude": "148.054", "latitude": "-37.375", "relative_humidity": "47", "air_temperature_celcius": "12"}
# Message published successfully. {"windspeed_knots": "3.6", "max_wind_speed": "7", "Sender_ID": "Producer01", "precipitation": "0.01G", "Created_Time": "2019-05-24 21:41:55", "longitude": "148.099", "latitude": "-37.453", "relative_humidity": "45.7", "air_temperature_celcius": "10"}
# Message published successfully. {"windspeed_knots": "6", "max_wind_speed": "13", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 21:42:00", "longitude": "149.312", "latitude": "-37.606", "relative_humidity": "51", "air_temperature_celcius": "16"}
# Message published successfully. {"windspeed_knots": "13.7", "max_wind_speed": "22", "Sender_ID": "Producer01", "precipitation": "0.03G", "Created_Time": "2019-05-24 21:42:05", "longitude": "148.081", "latitude": "-37.399", "relative_humidity": "49.9", "air_temperature_celcius": "14"}
# Message published successfully. {"windspeed_knots": "5.8", "max_wind_speed": "14", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:42:10", "longitude": "141.078", "latitude": "-35.963", "relative_humidity": "33.1", "air_temperature_celcius": "5"}
# Message published successfully. {"windspeed_knots": "10.5", "max_wind_speed": "20", "Sender_ID": "Producer01", "precipitation": "0
"air_temperature_celcius": "11"}
# Message published successfully. {"windspeed_knots": "14.4", "max_wind_speed": "19", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 21:44:15", "longitude": "149.296", "latitude": "-37.61", "relative_humidity": "48.3", "air_temperature_celcius": "16"}
# Message published successfully. {"windspeed_knots": "4.4", "max_wind_speed": "8.9", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:44:20", "longitude": "148.1", "latitude": "-37.466", "relative_humidity": "49.4", "air_temperature_celcius": "12"}
# Message published successfully. {"windspeed_knots": "4.6", "max_wind_speed": "8.9", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 21:44:25", "longitude": "141.232", "latitude": "-37.294", "relative_humidity": "49", "air_temperature_celcius": "12"}
# Message published successfully. {"windspeed_knots": "4.6", "max_wind_speed": "12", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:44:30", "longitude": "148.101", "latitude": "-37.444", "relative_humidity": "42", "air_temperature_celcius": "9"}
# Message published successfully. {"windspeed_knots": "11.5", "max_wind_speed": "18.1", "Sender_ID": "Producer01", "precipitation": "0.20G", "Created_Time": "2019-05-24 21:44:35", "longitude": "145.286", "latitude": "-36.398", "relative_humidity": "45.1", "air_temperature_celcius": "11"}
# Message published successfully. {"windspeed_knots": "14.1", "max_wind_speed": "20", "Sender_ID": "Producer01", "precipitation": "0.02G", "Created_Time": "2019-05-24 21:44:40", "longitude": "147.266", "latitude": "-37.497", "relative_humidity": "41", "air_temperature_celcius": "10"}
# Message published successfully. {"windspeed_knots": "8.8", "max_wind_speed": "15", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:44:45", "longitude": "141.4938", "latitude": "-36.2127", "relative_humidity": "58.8", "air_temperature_celcius": "23"}
# Message published successfully. {"windspeed_knots": "12.9", "max_wind_speed": "19", "Sender_ID": "Producer01", "precipitation": "0.02G", "Created_Time": "2019-05-24 21:44:50", "longitude": "142.7354", "latitude": "-36.7084", "relative_humidity": "44.1", "air_temperature_celcius": "13"}
# Message published successfully. {"windspeed_knots": "8", "max_wind_speed": "16.9", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:44:55", "longitude": "141.373", "latitude": "-37.062", "relative_humidity": "46.8", "air_temperature_celcius": "22"}
# Message published successfully. {"windspeed_knots": "14.4", "max_wind_speed": "23.9", "Sender_ID": "Producer01", "precipitation": "0.16G", "Created_Time": "2019-05-24 21:45:00", "longitude": "143.5051", "latitude": "-36.9817", "relative_humidity": "44", "air_temperature_celcius": "14"}
# Message published successfully. {"windspeed_knots": "6.9", "max_wind_speed": "9.9", "Sender_ID": "Producer01", "precipitation": "0.02G", "Created_Time": "2019-05-24 21:45:05", "longitude": "141.0692", "latitude": "-37.0745", "relative_humidity": "40.4", "air_temperature_celcius": "9"}
# Message published successfully. {"windspeed_knots": "9.7", "max_wind_speed": "14", "Sender_ID": "Producer01", "precipitation": "0.20G", "Created_Time": "2019-05-24 21:45:10", "longitude": "145.2096", "latitude": "-36.1462", "relative_humidity": "43.6", "air_temperature_celcius": "10"}
# Message published successfully. {"windspeed_knots": "10.4", "max_wind_speed": "16.9", "Sender_ID": "Producer01", "precipitation": "0.08G", "Created_Time": "2019-05-24 21:45:15", "longitude": "144.1375", "latitude": "-37.1405", "relative_humidity": "60.8", "air_temperature_celcius": "20"}
# Message published successfully. {"windspeed_knots": "3.9", "max_wind_speed": "8", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:45:20", "longitude": "148.043", "latitude": "-37.386", "relative_humidity": "43.3", "air_temperature_celcius": "8"}
# Message published successfully. {"windspeed_knots": "11.7", "max_wind_speed": "19", "Sender_ID": "Producer01", "precipitation": "0.04G", "Created_Time": "2019-05-24 21:45:25", "longitude": "143.735", "latitude": "-36.098", "relative_humidity": "58.1", "air_temperature_celcius": "17"}
# Message published successfully. {"windspeed_knots": "7.3", "max_wind_speed": "14", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 21:45:30", "longitude": "149.311", "latitude": "-37.602", "relative_humidity": "48.5", "air_temperature_celcius": "14"}
# Message published successfully. {"windspeed_knots": "4.3", "max_wind_speed": "11.1", "Sender_ID": "Producer01", "precipitation": "0.00A", "Created_Time": "2019-05-24 21:45:35", "longitude": "141.089", "latitude": "-35.961", "relative_humidity": "34.9", "air_temperature_celcius": "5"}
# Message published successfully. {"windspeed_knots": "10.1", "max_wind_speed": "26", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:45:40", "longitude": "143.358", "latitude": "-37.479", "relative_humidity": "60.6", "air_temperature_celcius": "23"}
# Message published successfully. {"windspeed_knots": "7.6", "max_wind_speed": "15", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:45:45", "longitude": "142.5651", "latitude": "-36.251", "relative_humidity": "53.6", "air_temperature_celcius": "17"}
# Message published successfully. {"windspeed_knots": "8.3", "max_wind_speed": "19", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:45:50", "longitude": "143.0558", "latitude": "-37.6008", "relative_humidity": "44.8", "air_temperature_celcius": "15"}
# Message published successfully. {"windspeed_knots": "14.6", "max_wind_speed": "22.9", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:45:55", "longitude": "144.1064", "latitude": "-37.9243", "relative_humidity": "53", "air_temperature_celcius": "17"}
# Message published successfully. {"windspeed_knots": "12.4", "max_wind_speed": "21", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:46:00", "longitude": "145.623", "latitude": "-37.978", "relative_humidity": "59.5", "air_temperature_celcius": "21"}
# Message published successfully. {"windspeed_knots": "10.2", "max_wind_speed": "15", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 21:46:05", "longitude": "145.606", "latitude": "-35.89", "relative_humidity": "45.6", "air_temperature_celcius": "15"}
# Message published successfully. {"windspeed_knots": "7.3", "max_wind_speed": "11.1", "Sender_ID": "Producer01", "precipitation": "0.03G", "Created_Time": "2019-05-24 21:46:10", "longitude": "144.392", "latitude": "-37.287", "relative_humidity": "48.2", "air_temperature_celcius": "12"}
# Message published successfully. {"windspeed_knots": "10.5", "max_wind_speed": "15", "Sender_ID": "Producer01", "precipitation": "0.28G", "Created_Time": "2019-05-24 21:46:15", "longitude": "141.828", "latitude": "-37.1104", "relative_humidity": "46.2", "air_temperature_celcius": "11"}
# Message published successfully. {"windspeed_knots": "13.1", "max_wind_speed": "21", "Sender_ID": "Producer01", "precipitation": "0.24G", "Created_Time": "2019-05-24 21:46:20", "longitude": "148.153", "latitude": "-37.465", "relative_humidity": "43.5", "air_temperature_celcius": "11"}
# Message published successfully. {"windspeed_knots": "6.5", "max_wind_speed": "8.9", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:46:25", "longitude": "148.089", "latitude": "-37.47", "relative_humidity": "46.4", "air_temperature_celcius": "11"}
# Message published successfully. {"windspeed_knots": "10.8", "max_wind_speed": "15", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 21:46:30", "longitude": "146.272", "latitude": "-38.912", "relative_humidity": "53.3", "air_temperature_celcius": "18"}
# Message published successfully. {"windspeed_knots": "5.5", "max_wind_speed": "11.1", "Sender_ID": "Producer01", "precipitation": "0.28G", "Created_Time": "2019-05-24 21:46:35", "longitude": "142.538", "latitude": "-36.701", "relative_humidity": "61.5", "air_temperature_celcius": "18"}
# Message published successfully. {"windspeed_knots": "8.6", "max_wind_speed": "13", "Sender_ID": "Producer01", "precipitation": "0.02G", "Created_Time": "2019-05-24 21:46:40", "longitude": "142.524", "latitude": "-36.834", "relative_humidity": "50.3", "air_temperature_celcius": "13"}
# Message published successfully. {"windspeed_knots": "6.6", "max_wind_speed": "11.1", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:46:45", "longitude": "146.791", "latitude": "-37.189", "relative_humidity": "61.1", "air_temperature_celcius": "21"}
# Message published successfully. {"windspeed_knots": "6.7", "max_wind_speed": "11.1", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:46:50", "longitude": "144.165", "latitude": "-36.764", "relative_humidity": "52.4", "air_temperature_celcius": "14"}
# Message published successfully. {"windspeed_knots": "7.4", "max_wind_speed": "15", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:46:55", "longitude": "149.232", "latitude": "-37.63", "relative_humidity": "57", "air_temperature_celcius": "18"}
# Message published successfully. {"windspeed_knots": "12.6", "max_wind_speed": "16.9", "Sender_ID": "Producer01", "precipitation": "0.08G", "Created_Time": "2019-05-24 21:47:00", "longitude": "148.25", "latitude": "-36.984", "relative_humidity": "39.9", "air_temperature_celcius": "10"}
# Message published successfully. {"windspeed_knots": "7.5", "max_wind_speed": "11.1", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:47:05", "longitude": "145.37", "latitude": "-37.087", "relative_humidity": "40.1", "air_temperature_celcius": "9"}
# Message published successfully. {"windspeed_knots": "11.9", "max_wind_speed": "22", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:47:10", "longitude": "143.185", "latitude": "-36.009", "relative_humidity": "48.3", "air_temperature_celcius": "28"}
# Message published successfully. {"windspeed_knots": "7.4", "max_wind_speed": "15", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:47:15", "longitude": "149.232", "latitude": "-37.63", "relative_humidity": "57", "air_temperature_celcius": "18"}
# Message published successfully. {"windspeed_knots": "9.2", "max_wind_speed": "15.9", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:47:20", "longitude": "143.605", "latitude": "-37.69", "relative_humidity": "45.7", "air_temperature_celcius": "14"}
# Message published successfully. {"windspeed_knots": "13.1", "max_wind_speed": "21", "Sender_ID": "Producer01", "precipitation": "0.24G", "Created_Time": "2019-05-24 21:47:25", "longitude": "148.153", "latitude": "-37.465", "relative_humidity": "43.5", "air_temperature_celcius": "11"}
# Message published successfully. {"windspeed_knots": "19.3", "max_wind_speed": "26", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 21:47:30", "longitude": "148.034", "latitude": "-37.57", "relative_humidity": "40.4", "air_temperature_celcius": "11"}
# Message published successfully. {"windspeed_knots": "6.7", "max_wind_speed": "14", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:47:35", "longitude": "142.9892", "latitude": "-37.6767", "relative_humidity": "53.8", "air_temperature_celcius": "18"}
# Message published successfully. {"windspeed_knots": "9.3", "max_wind_speed": "15", "Sender_ID": "Producer01", "precipitation": "0.20G", "Created_Time": "2019-05-24 21:47:40", "longitude": "144.3142", "latitude": "-36.4325", "relative_humidity": "61", "air_temperature_celcius": "26"}
# Message published successfully. {"windspeed_knots": "5.3", "max_wind_speed": "12", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 21:47:45", "longitude": "148.089", "latitude": "-37.462", "relative_humidity": "40.7", "air_temperature_celcius": "8"}
# Message published successfully. {"windspeed_knots": "5.3", "max_wind_speed": "9.9", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:47:50", "longitude": "143.818", "latitude": "-38.116", "relative_humidity": "46.8", "air_temperature_celcius": "10"}
# Message published successfully. {"windspeed_knots": "8.3", "max_wind_speed": "15.9", "Sender_ID": "Producer01", "precipitation": "0.24G", "Created_Time": "2019-05-24 21:47:55", "longitude": "141.145", "latitude": "-37.238", "relative_humidity": "41.6", "air_temperature_celcius": "8"}
# Message published successfully. {"windspeed_knots": "9.7", "max_wind_speed": "14", "Sender_ID": "Producer01", "precipitation": "0.02G", "Created_Time": "2019-05-24 21:48:01", "longitude": "142.524", "latitude": "-36.834", "relative_humidity": "47.3", "air_temperature_celcius": "12"}
# Message published successfully. {"windspeed_knots": "9.4", "max_wind_speed": "14", "Sender_ID": "Producer01", "precipitation": "0.01G", "Created_Time": "2019-05-24 21:48:06", "longitude": "149.32", "latitude": "-37.609", "relative_humidity": "48.3", "air_temperature_celcius": "16"}
# Message published successfully. {"windspeed_knots": "7.9", "max_wind_speed": "14", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:48:11", "longitude": "143.428", "latitude": "-37.858", "relative_humidity": "50.4", "air_temperature_celcius": "13"}
# Message published successfully. {"windspeed_knots": "6.8", "max_wind_speed": "11.1", "Sender_ID": "Producer01", "precipitation": "0.51G", "Created_Time": "2019-05-24 21:48:16", "longitude": "143.416", "latitude": "-37.856", "relative_humidity": "53.7", "air_temperature_celcius": "15"}
# Message published successfully. {"windspeed_knots": "6.1", "max_wind_speed": "11.1", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:48:21", "longitude": "143.447", "latitude": "-37.621", "relative_humidity": "53.4", "air_temperature_celcius": "23"}
# Message published successfully. {"windspeed_knots": "4.9", "max_wind_speed": "13", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:48:26", "longitude": "143.631", "latitude": "-36.346", "relative_humidity": "47.2", "air_temperature_celcius": "17"}
# Message published successfully. {"windspeed_knots": "6.7", "max_wind_speed": "14", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 21:48:31", "longitude": "143.1768", "latitude": "-36.2693", "relative_humidity": "46.6", "air_temperature_celcius": "12"}
# Message published successfully. {"windspeed_knots": "8.7", "max_wind_speed": "13", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:48:36", "longitude": "146.165", "latitude": "-36.277", "relative_humidity": "57", "air_temperature_celcius": "20"}
# Message published successfully. {"windspeed_knots": "5.9", "max_wind_speed": "14", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:48:41", "longitude": "144.233", "latitude": "-36.0856", "relative_humidity": "43.2", "air_temperature_celcius": "11"}
# Message published successfully. {"windspeed_knots": "10", "max_wind_speed": "15.9", "Sender_ID": "Producer01", "precipitation": "0.01G", "Created_Time": "2019-05-24 21:48:46", "longitude": "143.1906", "latitude": "-36.2669", "relative_humidity": "42.7", "air_temperature_celcius": "12"}
# Message published successfully. {"windspeed_knots": "13.8", "max_wind_speed": "16.9", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 21:48:51", "longitude": "148.107", "latitude": "-37.425", "relative_humidity": "41.2", "air_temperature_celcius": "15"}
# Message published successfully. {"windspeed_knots": "10.9", "max_wind_speed": "19", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:48:56", "longitude": "149.297", "latitude": "-37.6", "relative_humidity": "53.4", "air_temperature_celcius": "22"}
# Message published successfully. {"windspeed_knots": "7.4", "max_wind_speed": "14", "Sender_ID": "Producer01", "precipitation": "0.63G", "Created_Time": "2019-05-24 21:49:01", "longitude": "143.8589", "latitude": "-37.0585", "relative_humidity": "59.7", "air_temperature_celcius": "19"}
# Message published successfully. {"windspeed_knots": "5.9", "max_wind_speed": "13", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:49:06", "longitude": "144.7505", "latitude": "-36.3769", "relative_humidity": "50.9", "air_temperature_celcius": "14"}
# Message published successfully. {"windspeed_knots": "9.1", "max_wind_speed": "15", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:49:11", "longitude": "144.384", "latitude": "-37.297", "relative_humidity": "52.8", "air_temperature_celcius": "22"}
# Message published successfully. {"windspeed_knots": "12.8", "max_wind_speed": "19", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:49:16", "longitude": "145.179", "latitude": "-36.759", "relative_humidity": "55.6", "air_temperature_celcius": "18"}
# Message published successfully. {"windspeed_knots": "7.7", "max_wind_speed": "15", "Sender_ID": "Producer01", "precipitation": "0.03G", "Created_Time": "2019-05-24 21:49:21", "longitude": "144.6301", "latitude": "-37.8387", "relative_humidity": "41.4", "air_temperature_celcius": "11"}
# Message published successfully. {"windspeed_knots": "11.5", "max_wind_speed": "16.9", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 21:49:26", "longitude": "142.6069", "latitude": "-37.6836", "relative_humidity": "38.4", "air_temperature_celcius": "13"}
# Message published successfully. {"windspeed_knots": "5.9", "max_wind_speed": "13", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:49:31", "longitude": "144.7505", "latitude": "-36.3769", "relative_humidity": "50.9", "air_temperature_celcius": "14"}
# Message published successfully. {"windspeed_knots": "7.6", "max_wind_speed": "18.1", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:49:36", "longitude": "149.282", "latitude": "-37.608", "relative_humidity": "62.7", "air_temperature_celcius": "22"}
# Message published successfully. {"windspeed_knots": "5.3", "max_wind_speed": "12", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 21:49:41", "longitude": "148.089", "latitude": "-37.462", "relative_humidity": "40.7", "air_temperature_celcius": "8"}
# Message published successfully. {"windspeed_knots": "9", "max_wind_speed": "15", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:49:46", "longitude": "144.961", "latitude": "-36.5871", "relative_humidity": "43.6", "air_temperature_celcius": "13"}
# Message published successfully. {"windspeed_knots": "10", "max_wind_speed": "13", "Sender_ID": "Producer01", "precipitation": "0.02G", "Created_Time": "2019-05-24 21:49:51", "longitude": "141.151", "latitude": "-37.227", "relative_humidity": "41.2", "air_temperature_celcius": "9"}
# Message published successfully. {"windspeed_knots": "6.5", "max_wind_speed": "9.9", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 21:49:56", "longitude": "143.593", "latitude": "-37.692", "relative_humidity": "45.8", "air_temperature_celcius": "14"}
# Message published successfully. {"windspeed_knots": "9.9", "max_wind_speed": "18.1", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:50:01", "longitude": "146.149", "latitude": "-36.294", "relative_humidity": "57.7", "air_temperature_celcius": "20"}
# Message published successfully. {"windspeed_knots": "10.3", "max_wind_speed": "15", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:50:06", "longitude": "142.8935", "latitude": "-37.3847", "relative_humidity": "43.6", "air_temperature_celcius": "20"}
# Message published successfully. {"windspeed_knots": "12.1", "max_wind_speed": "15", "Sender_ID": "Producer01", "precipitation": "0.08G", "Created_Time": "2019-05-24 21:50:11", "longitude": "143.3445", "latitude": "-37.6593", "relative_humidity": "40.1", "air_temperature_celcius": "9"}
# Message published successfully. {"windspeed_knots": "11", "max_wind_speed": "19", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:50:16", "longitude": "142.5191", "latitude": "-36.6296", "relative_humidity": "49.9", "air_temperature_celcius": "28"}
# Message published successfully. {"windspeed_knots": "12.5", "max_wind_speed": "21", "Sender_ID": "Producer01", "precipitation": "0.47G", "Created_Time": "2019-05-24 21:50:21", "longitude": "143.123", "latitude": "-37.34", "relative_humidity": "52.8", "air_temperature_celcius": "19"}
# Message published successfully. {"windspeed_knots": "6.5", "max_wind_speed": "8.9", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:50:26", "longitude": "148.089", "latitude": "-37.47", "relative_humidity": "46.4", "air_temperature_celcius": "11"}
# Message published successfully. {"windspeed_knots": "9.2", "max_wind_speed": "13", "Sender_ID": "Producer01", "precipitation": "0.02G", "Created_Time": "2019-05-24 21:50:31", "longitude": "142.986", "latitude": "-38.038", "relative_humidity": "50.7", "air_temperature_celcius": "15"}
# Message published successfully. {"windspeed_knots": "3.9", "max_wind_speed": "8", "Sender_ID": "Producer01", "precipitation": "0.39G", "Created_Time": "2019-05-24 21:50:36", "longitude": "146.944", "latitude": "-38.495", "relative_humidity": "44.6", "air_temperature_celcius": "8"}
# Message published successfully. {"windspeed_knots": "9.9", "max_wind_speed": "15", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:50:41", "longitude": "148.053", "latitude": "-37.38", "relative_humidity": "51", "air_temperature_celcius": "14"}
# Message published successfully. {"windspeed_knots": "8.9", "max_wind_speed": "15", "Sender_ID": "Producer01", "precipitation": "0.01G", "Created_Time": "2019-05-24 21:50:46", "longitude": "149.307", "latitude": "-37.61", "relative_humidity": "55.5", "air_temperature_celcius": "18"}
# Message published successfully. {"windspeed_knots": "6.5", "max_wind_speed": "8.9", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:50:51", "longitude": "148.089", "latitude": "-37.47", "relative_humidity": "46.4", "air_temperature_celcius": "11"}
# Message published successfully. {"windspeed_knots": "16.7", "max_wind_speed": "21", "Sender_ID": "Producer01", "precipitation": "0.12G", "Created_Time": "2019-05-24 21:50:56", "longitude": "148.104", "latitude": "-37.437", "relative_humidity": "40.7", "air_temperature_celcius": "12"}
# Message published successfully. {"windspeed_knots": "12.1", "max_wind_speed": "19", "Sender_ID": "Producer01", "precipitation": "0.04G", "Created_Time": "2019-05-24 21:51:01", "longitude": "141.153", "latitude": "-37.242", "relative_humidity": "42.8", "air_temperature_celcius": "12"}
# Message published successfully. {"windspeed_knots": "4.2", "max_wind_speed": "7", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:51:06", "longitude": "145.362", "latitude": "-37.091", "relative_humidity": "48.8", "air_temperature_celcius": "12"}
# Message published successfully. {"windspeed_knots": "7.9", "max_wind_speed": "15", "Sender_ID": "Producer01", "precipitation": "0.01G", "Created_Time": "2019-05-24 21:51:11", "longitude": "142.2098", "latitude": "-36.8835", "relative_humidity": "41.6", "air_temperature_celcius": "11"}
# Message published successfully. {"windspeed_knots": "3.9", "max_wind_speed": "8", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 21:51:16", "longitude": "148.043", "latitude": "-37.386", "relative_humidity": "43.3", "air_temperature_celcius": "8"}
# ...
# Message published successfully. {"windspeed_knots": "5.7", "max_wind_speed": "9.9", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 22:41:55", "longitude": "142.0839", "latitude": "-36.5243", "relative_humidity": "43.9", "air_temperature_celcius": "9"}
# Message published successfully. {"windspeed_knots": "8.5", "max_wind_speed": "12", "Sender_ID": "Producer01", "precipitation": "0.08G", "Created_Time": "2019-05-24 22:42:00", "longitude": "143.7132", "latitude": "-36.369", "relative_humidity": "50.1", "air_temperature_celcius": "13"}
# Message published successfully. {"windspeed_knots": "6.5", "max_wind_speed": "12", "Sender_ID": "Producer01", "precipitation": "0.02G", "Created_Time": "2019-05-24 22:42:05", "longitude": "148.052", "latitude": "-37.365", "relative_humidity": "43.8", "air_temperature_celcius": "11"}
# Message published successfully. {"windspeed_knots": "8.1", "max_wind_speed": "15", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 22:42:10", "longitude": "143.292", "latitude": "-36.942", "relative_humidity": "51.1", "air_temperature_celcius": "18"}
# Message published successfully. {"windspeed_knots": "7.7", "max_wind_speed": "14", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 22:42:15", "longitude": "148.091", "latitude": "-37.332", "relative_humidity": "39.3", "air_temperature_celcius": "8"}
# Message published successfully. {"windspeed_knots": "9", "max_wind_speed": "15.9", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 22:42:20", "longitude": "149.295", "latitude": "-37.602", "relative_humidity": "50.8", "air_temperature_celcius": "17"}
# Message published successfully. {"windspeed_knots": "14.6", "max_wind_speed": "22.9", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 22:42:25", "longitude": "144.1064", "latitude": "-37.9243", "relative_humidity": "53", "air_temperature_celcius": "17"}
# Message published successfully. {"windspeed_knots": "16.1", "max_wind_speed": "21", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 22:42:30", "longitude": "144.17", "latitude": "-37.863", "relative_humidity": "57.5", "air_temperature_celcius": "18"}
# Message published successfully. {"windspeed_knots": "6.5", "max_wind_speed": "12", "Sender_ID": "Producer01", "precipitation": "0.02G", "Created_Time": "2019-05-24 22:42:35", "longitude": "148.052", "latitude": "-37.365", "relative_humidity": "43.8", "air_temperature_celcius": "11"}
# Message published successfully. {"windspeed_knots": "5.9", "max_wind_speed": "12", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 22:42:40", "longitude": "147.207", "latitude": "-37.886", "relative_humidity": "54.3", "air_temperature_celcius": "19"}
# Message published successfully. {"windspeed_knots": "5.3", "max_wind_speed": "9.9", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 22:42:45", "longitude": "143.818", "latitude": "-38.116", "relative_humidity": "46.8", "air_temperature_celcius": "10"}
# Message published successfully. {"windspeed_knots": "14.5", "max_wind_speed": "20", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 22:42:50", "longitude": "148.099", "latitude": "-37.333", "relative_humidity": "35.6", "air_temperature_celcius": "10"}
# Message published successfully. {"windspeed_knots": "5.7", "max_wind_speed": "11.1", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 22:42:55", "longitude": "142.5058", "latitude": "-36.6312", "relative_humidity": "52.5", "air_temperature_celcius": "17"}
# Message published successfully. {"windspeed_knots": "4.1", "max_wind_speed": "11.1", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 22:43:00", "longitude": "143.281", "latitude": "-36.94", "relative_humidity": "52.8", "air_temperature_celcius": "21"}
# Message published successfully. {"windspeed_knots": "12.3", "max_wind_speed": "18.1", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 22:43:05", "longitude": "143.4996", "latitude": "-36.9364", "relative_humidity": "41.7", "air_temperature_celcius": "14"}
# Message published successfully. {"windspeed_knots": "4.7", "max_wind_speed": "7", "Sender_ID": "Producer01", "precipitation": "0.01G", "Created_Time": "2019-05-24 22:43:10", "longitude": "141.182", "latitude": "-37.229", "relative_humidity": "44.5", "air_temperature_celcius": "8"}
# Message published successfully. {"windspeed_knots": "10.8", "max_wind_speed": "16.9", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 22:43:15", "longitude": "146.7777", "latitude": "-37.1815", "relative_humidity": "50.4", "air_temperature_celcius": "17"}
# Message published successfully. {"windspeed_knots": "11.9", "max_wind_speed": "16.9", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 22:43:20", "longitude": "146.157", "latitude": "-36.282", "relative_humidity": "50.4", "air_temperature_celcius": "17"}
# Message published successfully. {"windspeed_knots": "10.3", "max_wind_speed": "15", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 22:43:25", "longitude": "142.8935", "latitude": "-37.3847", "relative_humidity": "43.6", "air_temperature_celcius": "20"}
# Message published successfully. {"windspeed_knots": "10.2", "max_wind_speed": "14", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 22:43:30", "longitude": "142.9848", "latitude": "-37.6745", "relative_humidity": "44.5", "air_temperature_celcius": "15"}
# Message published successfully. {"windspeed_knots": "7.7", "max_wind_speed": "14", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 22:43:35", "longitude": "144.6926", "latitude": "-37.7052", "relative_humidity": "52.7", "air_temperature_celcius": "17"}
# Message published successfully. {"windspeed_knots": "5.5", "max_wind_speed": "11.1", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 22:43:40", "longitude": "145.2196", "latitude": "-36.1346", "relative_humidity": "37.2", "air_temperature_celcius": "8"}
# Message published successfully. {"windspeed_knots": "5.8", "max_wind_speed": "12", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 22:43:45", "longitude": "146.148", "latitude": "-36.293", "relative_humidity": "50.8", "air_temperature_celcius": "16"}
# Message published successfully. {"windspeed_knots": "10.7", "max_wind_speed": "22.9", "Sender_ID": "Producer01", "precipitation": "0.67G", "Created_Time": "2019-05-24 22:43:50", "longitude": "142.5598", "latitude": "-36.4025", "relative_humidity": "57.4", "air_temperature_celcius": "21"}
# Message published successfully. {"windspeed_knots": "7.8", "max_wind_speed": "14", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 22:43:55", "longitude": "141.2419", "latitude": "-35.0889", "relative_humidity": "44.4", "air_temperature_celcius": "12"}
# Message published successfully. {"windspeed_knots": "4.2", "max_wind_speed": "7", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 22:44:00", "longitude": "145.362", "latitude": "-37.091", "relative_humidity": "48.8", "air_temperature_celcius": "12"}
# Message published successfully. {"windspeed_knots": "6.6", "max_wind_speed": "14", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 22:44:05", "longitude": "149.311", "latitude": "-37.389", "relative_humidity": "53", "air_temperature_celcius": "18"}
# Message published successfully. {"windspeed_knots": "9.9", "max_wind_speed": "18.1", "Sender_ID": "Producer01", "precipitation": "0.01G", "Created_Time": "2019-05-24 22:44:10", "longitude": "149.334", "latitude": "-37.38", "relative_humidity": "48.2", "air_temperature_celcius": "16"}
# Message published successfully. {"windspeed_knots": "9", "max_wind_speed": "13", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 22:44:15", "longitude": "143.1057", "latitude": "-35.779", "relative_humidity": "53.7", "air_temperature_celcius": "18"}
# Message published successfully. {"windspeed_knots": "6.6", "max_wind_speed": "11.1", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 22:44:20", "longitude": "146.791", "latitude": "-37.189", "relative_humidity": "61.1", "air_temperature_celcius": "21"}
# Message published successfully. {"windspeed_knots": "7.3", "max_wind_speed": "13", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 22:44:25", "longitude": "142.9874", "latitude": "-37.6662", "relative_humidity": "51.9", "air_temperature_celcius": "24"}
# Message published successfully. {"windspeed_knots": "8.6", "max_wind_speed": "22.9", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 22:44:30", "longitude": "141.2821", "latitude": "-36.9085", "relative_humidity": "47.3", "air_temperature_celcius": "15"}
# Message published successfully. {"windspeed_knots": "7.1", "max_wind_speed": "14", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 22:44:35", "longitude": "141.278", "latitude": "-37.247", "relative_humidity": "47.4", "air_temperature_celcius": "14"}
# Message published successfully. {"windspeed_knots": "11.9", "max_wind_speed": "22", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 22:44:40", "longitude": "143.185", "latitude": "-36.009", "relative_humidity": "48.3", "air_temperature_celcius": "28"}
# Message published successfully. {"windspeed_knots": "7.1", "max_wind_speed": "15", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 22:44:45", "longitude": "143.803", "latitude": "-38.16", "relative_humidity": "62.2", "air_temperature_celcius": "20"}
# Message published successfully. {"windspeed_knots": "13.6", "max_wind_speed": "21", "Sender_ID": "Producer01", "precipitation": "0.04G", "Created_Time": "2019-05-24 22:44:50", "longitude": "148.121", "latitude": "-37.397", "relative_humidity": "44", "air_temperature_celcius": "13"}
# Message published successfully. {"windspeed_knots": "8.7", "max_wind_speed": "15.9", "Sender_ID": "Producer01", "precipitation": "0.04G", "Created_Time": "2019-05-24 22:44:55", "longitude": "148.113", "latitude": "-37.46", "relative_humidity": "44.2", "air_temperature_celcius": "11"}
# Message published successfully. {"windspeed_knots": "11", "max_wind_speed": "19", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 22:45:00", "longitude": "142.5191", "latitude": "-36.6296", "relative_humidity": "49.9", "air_temperature_celcius": "28"}
# Message published successfully. {"windspeed_knots": "6.2", "max_wind_speed": "12", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 22:45:05", "longitude": "142.8786", "latitude": "-36.4553", "relative_humidity": "55.3", "air_temperature_celcius": "19"}
# Message published successfully. {"windspeed_knots": "7.4", "max_wind_speed": "15", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 22:45:10", "longitude": "149.232", "latitude": "-37.63", "relative_humidity": "57", "air_temperature_celcius": "18"}
# Message published successfully. {"windspeed_knots": "6.9", "max_wind_speed": "9.9", "Sender_ID": "Producer01", "precipitation": "0.02G", "Created_Time": "2019-05-24 22:45:15", "longitude": "141.0692", "latitude": "-37.0745", "relative_humidity": "40.4", "air_temperature_celcius": "9"}
# Message published successfully. {"windspeed_knots": "8.7", "max_wind_speed": "15", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 22:45:20", "longitude": "149.261", "latitude": "-37.627", "relative_humidity": "53.7", "air_temperature_celcius": "26"}
# Message published successfully. {"windspeed_knots": "10", "max_wind_speed": "19", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 22:45:25", "longitude": "149.326", "latitude": "-37.605", "relative_humidity": "49.6", "air_temperature_celcius": "23"}
# Message published successfully. {"windspeed_knots": "14.4", "max_wind_speed": "20", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 22:45:30", "longitude": "143.0551", "latitude": "-37.5268", "relative_humidity": "35", "air_temperature_celcius": "8"}
# Message published successfully. {"windspeed_knots": "6.7", "max_wind_speed": "14", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 22:45:35", "longitude": "143.1768", "latitude": "-36.2693", "relative_humidity": "46.6", "air_temperature_celcius": "12"}
# Message published successfully. {"windspeed_knots": "13.2", "max_wind_speed": "20", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 22:45:40", "longitude": "143.136", "latitude": "-37.329", "relative_humidity": "47", "air_temperature_celcius": "21"}
# Message published successfully. {"windspeed_knots": "2.8", "max_wind_speed": "8", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 22:45:45", "longitude": "143.82", "latitude": "-38.127", "relative_humidity": "44", "air_temperature_celcius": "9"}
# Message published successfully. {"windspeed_knots": "8.5", "max_wind_speed": "20", "Sender_ID": "Producer01", "precipitation": "0.01G", "Created_Time": "2019-05-24 22:45:50", "longitude": "143.7295", "latitude": "-36.3674", "relative_humidity": "48.7", "air_temperature_celcius": "15"}
# Message published successfully. {"windspeed_knots": "7.9", "max_wind_speed": "15", "Sender_ID": "Producer01", "precipitation": "0.01G", "Created_Time": "2019-05-24 22:45:55", "longitude": "142.2098", "latitude": "-36.8835", "relative_humidity": "41.6", "air_temperature_celcius": "11"}
# Message published successfully. {"windspeed_knots": "9.3", "max_wind_speed": "18.1", "Sender_ID": "Producer01", "precipitation": "0.98G", "Created_Time": "2019-05-24 22:46:00", "longitude": "141.259", "latitude": "-37.588", "relative_humidity": "52.8", "air_temperature_celcius": "14"}
# Message published successfully. {"windspeed_knots": "10.6", "max_wind_speed": "19", "Sender_ID": "Producer01", "precipitation": "0.03G", "Created_Time": "2019-05-24 22:46:05", "longitude": "143.6296", "latitude": "-36.0313", "relative_humidity": "47.4", "air_temperature_celcius": "14"}
# Message published successfully. {"windspeed_knots": "16.1", "max_wind_speed": "27", "Sender_ID": "Producer01", "precipitation": "0.24G", "Created_Time": "2019-05-24 22:46:10", "longitude": "143.7313", "latitude": "-36.3782", "relative_humidity": "44.9", "air_temperature_celcius": "17"}
# Message published successfully. {"windspeed_knots": "9", "max_wind_speed": "15.9", "Sender_ID": "Producer01", "precipitation": "0.00G", "Created_Time": "2019-05-24 22:46:15", "longitude": "149.295", "latitude": "-37.602", "relative_humidity": "50.8", "air_temperature_celcius": "17"}
# Message published successfully. {"windspeed_knots": "10.9", "max_wind_speed": "19", "Sender_ID": "Producer01", "precipitation": "0.00I", "Created_Time": "2019-05-24 22:46:20", "longitude": "149.297", "latitude": "-37.6", "relative_humidity": "53.4", "air_temperature_celcius": "22"}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-f96e499be2f5> in <module>()
#      14     publish_message(producer01, topic, 'Producer01', json.dumps(data))
#      15     # Sleep for 5 seconds
# ---> 16     sleep(5)
#
# KeyboardInterrupt:
